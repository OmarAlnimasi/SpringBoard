# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import waterfall_chart

# %%
# !pip install waterfallcharts
# Out:
# ...
#   Created wheel for waterfallcharts: filename=waterfallcharts-3.8-py3-none-any.whl size=3413 sha256=86d04cc488f37eb895c7ac41dfa25d29ba899638421aacf122578c2e7ab552b4
#   Stored in directory: /Users/m7/Library/Caches/pip/wheels/3a/f4/33/2b1d12e4f5fb584718fce4ed86786549815863ef7276ff1415
# Successfully built waterfallcharts
# ...

# %%
df = pd.read_csv('millenniumofdata_v3_headlines.csv')

# %%
df.head()
# Out:
#   Description      Real GDP of England at market prices  \
# 0       Units  £mn, Chained Volume measure, 2013 prices
# 1        1209                                       NaN
# 2        1210                                       NaN
# 3        1211                                       NaN
# 4        1212                                       NaN
#
#         Real GDP of England at factor cost   \
# 0  £mn, Chained Volume measure, 2013 prices
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0           £mn, Chained Volume measure, 2013 prices
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#     Description      Real GDP of England at market prices  \
# 0         Units  £mn, Chained Volume measure, 2013 prices
# 721        1929                                    215534
# 722        1930                                    213608
# 723        1931                                    202987
# 724        1932                                    203872
#
#           Real GDP of England at factor cost   \
# 0    £mn, Chained Volume measure, 2013 prices
# 721                                    182494
# 722                                    180903
# 723                                    171948
# 724                                    172808
#
#     Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0             £mn, Chained Volume measure, 2013 prices
# 721                                             245205
# 722                                             243254
# 723                                             231969
# ...

# %%
df.columns
# Out:
# Index(['Description', 'Real GDP of England at market prices',
#        'Real GDP of England at factor cost ',
#        'Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders',
#        'Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders',
#        'Index of real UK GDP at factor cost - based on changing political boundaries, ',
#        'Composite estimate of English and (geographically-consistent) UK real GDP at factor cost',
#        'HP-filter of log of real composite estimate of English and UK real GDP at factor cost',
#        'Real UK gross disposable national income at market prices, constant border estimate',
#        'Real consumption', 'Real investment', 'Stockbuilding contribution',
#        'Real government consumption of goods and services', 'Export volumes',
#        'Import volumes', 'Nominal GDP of England at market prices',
# ...

# %%
df = df.iloc[1: , :]

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column])
# Out:
# /var/folders/1j/ls8q4cg97hn3bvrkmbd7ksl80000gn/T/ipykernel_13002/2713033711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column])

# %%
columns=df.columns
columns=columns[1:]

# %%
df[columns].describe()
# Out:
#        Real GDP of England at market prices  \
# count                          8.800000e+01
# mean                           7.514982e+05
# std                            4.514957e+05
# min                            2.029870e+05
# 25%                            3.340172e+05
# 50%                            6.730925e+05
# 75%                            1.076000e+06
# max                            1.672084e+06
#
#        Real GDP of England at factor cost   \
# count                         8.800000e+01
# mean                          6.309082e+05
# std                           3.755586e+05
# min                           1.719480e+05
# 25%                           2.856000e+05
# 50%                           5.629990e+05
# 75%                           8.983555e+05
# max                           1.413759e+06
#
#        Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# count                                       8.800000e+01
# ...

# %% [markdown]
# As we can see here, some columns can be best described by a line plot, others by a scatter plot, and some by a waterfall plot. So let's explore a lottle bit more. For example, real GDP is best describe by a line since we are trying to track trends through time

# %%
fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(111)
sns.lineplot(data=df,x='Description',y='Real GDP of England at market prices')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# Furthermore, we can plot employment vs year, and add the unemployment rate by setting up a bubble graph

# %%
fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(111)
sns.scatterplot(data=df,x='Description',y='Employment',size='Unemployment rate')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# We can also use an area chart to compare export and import over time.

# %%
df1=df[['Description','Export prices', 'Import prices']]

# %%
fig = plt.figure(figsize=(18,14))
ax = fig.add_subplot(111)
plt.stackplot(df1['Description'], df1['Export prices'], df1['Import prices'],
              labels=['Export', 'Import'])
plt.show()

# %% [markdown]
# Another type of graphs we can use is a waterfall graph, this is the best option to represent the exchange rate for example.

# %%
x=df['Description']
y=df['Trade deficit']
x=x[:80]
y=y[:80]
waterfall_chart.plot(x, y,sorted_value=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
